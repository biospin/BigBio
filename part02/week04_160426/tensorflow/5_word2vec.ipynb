# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
! pip install -U scikit-learn
# Out:
# Collecting scikit-learn
# /usr/local/lib/python2.7/dist-packages/pip/_vendor/requests/packages/urllib3/util/ssl_.py:315: SNIMissingWarning: An HTTPS request has been made, but the SNI (Subject Name Indication) extension to TLS is not available on this platform. This may cause the server to present an incorrect TLS certificate, which can cause validation failures. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#snimissingwarning.
#   SNIMissingWarning
# /usr/local/lib/python2.7/dist-packages/pip/_vendor/requests/packages/urllib3/util/ssl_.py:120: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
#   Downloading scikit_learn-0.17.1-cp27-cp27mu-manylinux1_x86_64.whl (17.6MB)
#     100% |################################| 17.6MB 53kB/s
# Installing collected packages: scikit-learn
# Successfully installed scikit-learn-0.17.1

# %%
! apt-get install python-numpy python-scipy python-matplotlib -y

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# - Build the dictionary and replace rare words with UNK token.
# - 단어사전을 만들고, 빈도가 낮은 단어는 UNK로 표시함

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'term', 'originated', 'a', 'term', 'originated', 'of', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.297348
# Nearest to its: brodsky, lvarez, sizable, electrophysiology, opteron, damnation, intensities, caravans,
# Nearest to united: lexis, erhard, fps, contested, shamir, cotswold, indebted, quantization,
# Nearest to most: minefields, remember, backing, sizing, climate, smoother, fernandez, helpful,
# Nearest to or: criticism, cutter, garlic, convergent, incunabula, eduard, kumamoto, prespa,
# Nearest to if: predicated, hunts, knowable, banchan, secessionist, attracts, wushu, agreements,
# Nearest to on: ineffective, commissar, morel, neoplatonism, sits, campaigner, effeminate, supercharged,
# Nearest to often: bogies, vj, eredivisie, aram, myoglobin, tupac, renovated, tremont,
# Nearest to five: rickenbacker, oud, americas, future, lascaux, playwrights, quarters, pluralism,
# Nearest to many: leicester, prod, realistic, centriole, fouled, cantons, gmbh, pep,
# Nearest to will: muggs, maltose, afrikaners, bathroom, bounding, rims, cubical, sampa,
# Nearest to th: delle, render, huike, capetian, beets, crookes, mistook, kanu,
# Nearest to had: cath, painterly, friz, wavefunction, ethnographers, vicarious, promulgation, undivided,
# Nearest to during: nb, lucifer, anaheim, yusuf, onion, lng, structuring, specialty,
# Nearest to be: roderick, monographs, regional, superpower, melanesia, temperance, aggregated, graced,
# Nearest to to: equine, eccl, poked, eid, hamdi, cometary, weill, accusative,
# Nearest to has: fifteen, welsh, shipwrecked, raphaelite, inquiring, bernard, agnesi, mormon,
# Average loss at step 2000: 4.357726
# Average loss at step 4000: 3.867999
# Average loss at step 6000: 3.786454
# Average loss at step 8000: 3.685559
# Average loss at step 10000: 3.616208
# Nearest to its: the, their, his, visually, straddling, shortening, reshaping, sizable,
# Nearest to united: arabized, in, amperes, bart, salad, umts, fps, lombardo,
# Nearest to most: anderson, throbbing, possibly, robo, remember, version, sobib, agora,
# Nearest to or: and, than, moksha, convergent, proudest, christian, alternation, masturbation,
# Nearest to if: predicated, unconcerned, knowable, weather, adopt, hunts, stallion, vipers,
# Nearest to on: in, at, neoplatonism, swims, protozoa, with, alternation, into,
# Nearest to often: bogies, vj, not, nicht, deeply, matte, been, no,
# Nearest to five: six, eight, four, seven, three, nine, zero, two,
# Nearest to many: some, hellish, culprit, more, schwann, rask, centriole, vu,
# Nearest to will: would, can, reuters, stunts, reinforces, raw, dip, apostrophe,
# Nearest to th: delle, render, carl, four, binaries, eight, untested, kanu,
# Nearest to had: has, have, was, cath, painterly, ethnographers, would, bested,
# Nearest to during: in, nb, annette, onion, bra, including, luggage, on,
# Nearest to be: have, eyesight, is, roderick, whipple, gunned, been, enterprising,
# Nearest to to: poked, would, anacletus, articulations, equine, eccl, from, will,
# Nearest to has: had, is, was, have, abhorrent, agnesi, but, although,
# Average loss at step 12000: 3.604700
# Average loss at step 14000: 3.571690
# Average loss at step 16000: 3.408764
# Average loss at step 18000: 3.457670
# Average loss at step 20000: 3.542041
# Nearest to its: their, his, the, reshaping, shortening, visually, any, straddling,
# Nearest to united: amperes, arabized, salad, lombardo, bart, fps, illness, motorcyclist,
# Nearest to most: many, more, adria, robo, throbbing, squatters, diet, version,
# Nearest to or: and, than, for, convinces, proudest, expos, extremity, truetype,
# Nearest to if: when, vipers, confounding, predicated, because, wheeler, knowable, enlarging,
# Nearest to on: in, protozoa, at, through, before, into, campaigner, against,
# Nearest to often: sometimes, still, also, commonly, who, generally, recruit, bogies,
# Nearest to five: three, seven, four, eight, six, two, zero, nine,
# Nearest to many: some, several, other, most, these, davidian, all, hellish,
# Nearest to will: would, can, could, cannot, stunts, may, must, to,
# Nearest to th: carl, delle, seven, untested, embargo, legalism, render, capetian,
# Nearest to had: has, have, was, were, having, would, bested, brevity,
# Nearest to during: in, at, nb, throughout, annette, controls, after, facing,
# Nearest to be: been, have, is, eyesight, become, by, whipple, enterprising,
# Nearest to to: must, not, will, eccl, would, for, staffed, rockets,
# Nearest to has: had, have, is, was, agnesi, having, although, abhorrent,
# Average loss at step 22000: 3.502057
# Average loss at step 24000: 3.490105
# Average loss at step 26000: 3.476491
# Average loss at step 28000: 3.486493
# Average loss at step 30000: 3.505324
# Nearest to its: their, his, the, carotene, assent, her, pencils, visually,
# Nearest to united: salad, amperes, arabized, bart, lombardo, fps, motorcyclist, fouled,
# Nearest to most: more, many, adria, squatters, some, use, anni, financial,
# Nearest to or: and, than, rumble, scandinavians, moorish, masturbation, expansionary, oubangui,
# Nearest to if: when, because, since, where, though, should, addictions, for,
# Nearest to on: in, during, through, under, from, at, into, for,
# Nearest to often: sometimes, commonly, generally, also, still, there, usually, they,
# Nearest to five: four, seven, eight, six, three, nine, zero, two,
# Nearest to many: some, several, these, most, davidian, other, all, both,
# Nearest to will: would, can, could, may, cannot, must, might, stunts,
# Nearest to th: carl, six, delle, legalism, st, seven, defunct, eight,
# Nearest to had: has, have, was, were, having, is, rips, would,
# Nearest to during: in, after, nb, at, throughout, on, before, annette,
# Nearest to be: have, been, is, refer, whipple, zbigniew, was, were,
# Nearest to to: would, will, can, panini, must, could, accusative, staffed,
# Nearest to has: had, have, is, was, having, agnesi, guerilla, tenths,
# Average loss at step 32000: 3.501198
# Average loss at step 34000: 3.490664
# Average loss at step 36000: 3.454698
# Average loss at step 38000: 3.304660
# Average loss at step 40000: 3.427789
# Nearest to its: their, his, the, her, pencils, carotene, assent, cohomology,
# Nearest to united: salad, lombardo, amperes, arabized, fouled, laserdisc, resolvers, embryo,
# Nearest to most: more, many, some, adria, less, squatters, anni, among,
# Nearest to or: and, than, lubavitch, scandinavians, oubangui, liqueurs, a, cosgrave,
# Nearest to if: when, where, because, though, for, obe, addictions, enlarging,
# Nearest to on: upon, at, during, in, concurred, within, adamantly, protozoa,
# Nearest to often: sometimes, usually, commonly, also, generally, still, there, who,
# Nearest to five: seven, six, four, eight, three, zero, nine, two,
# Nearest to many: some, several, these, most, various, both, davidian, other,
# Nearest to will: can, would, could, may, must, cannot, might, should,
# Nearest to th: st, carl, bc, delle, legalism, ce, detachments, defunct,
# Nearest to had: has, have, was, were, never, would, brevity, fists,
# Nearest to during: after, throughout, at, before, on, in, under, nb,
# Nearest to be: have, been, are, was, become, were, is, being,
# Nearest to to: must, will, may, eccl, could, can, would, shrinking,
# Nearest to has: had, have, is, was, agnesi, hamitic, gratis, hunnish,
# Average loss at step 42000: 3.439565
# Average loss at step 44000: 3.448091
# Average loss at step 46000: 3.449062
# Average loss at step 48000: 3.355034
# Average loss at step 50000: 3.385678
# Nearest to its: their, his, the, her, carotene, whose, our, hydroponic,
# Nearest to united: salad, arabized, city, runciman, heresiologists, lombardo, amperes, pontificia,
# Nearest to most: more, less, many, use, among, adria, some, circulation,
# Nearest to or: and, than, avid, fever, conducting, scandinavians, but, gaians,
# Nearest to if: when, where, though, since, because, vipers, attracts, while,
# Nearest to on: upon, through, in, at, across, over, inevitably, into,
# Nearest to often: sometimes, generally, commonly, usually, frequently, also, still, now,
# Nearest to five: four, six, seven, eight, three, zero, two, nine,
# Nearest to many: some, several, these, various, both, most, numerous, those,
# Nearest to will: would, can, could, may, must, cannot, might, should,
# Nearest to th: ce, bc, vestibule, st, legalism, carl, bce, delle,
# Nearest to had: has, have, was, were, having, rips, vorder, been,
# Nearest to during: after, at, throughout, when, before, in, under, despite,
# Nearest to be: have, were, been, are, being, become, was, is,
# Nearest to to: would, could, wftu, articulations, towards, eccl, recordable, can,
# Nearest to has: had, have, is, was, having, agnesi, legate, bested,
# Average loss at step 52000: 3.437482
# Average loss at step 54000: 3.430298
# Average loss at step 56000: 3.435873
# Average loss at step 58000: 3.394404
# Average loss at step 60000: 3.394421
# Nearest to its: their, his, the, her, earldom, whose, pencils, hydroponic,
# Nearest to united: salad, arabized, city, cooperative, bjorn, amperes, lombardo, following,
# Nearest to most: many, more, some, use, less, circulation, adria, edge,
# Nearest to or: and, than, for, scandinavians, but, disambiguate, expos, miko,
# Nearest to if: when, where, though, since, before, although, because, rotations,
# Nearest to on: upon, through, within, frenchmen, in, during, misfits, exact,
# Nearest to often: sometimes, commonly, usually, generally, frequently, also, now, typically,
# Nearest to five: four, six, eight, three, seven, zero, nine, two,
# Nearest to many: some, several, these, various, both, most, other, such,
# Nearest to will: would, can, could, may, must, cannot, might, should,
# Nearest to th: ce, five, st, bc, six, eight, legalism, bce,
# Nearest to had: has, have, was, were, received, having, brevity, preview,
# Nearest to during: after, before, when, in, despite, at, although, following,
# Nearest to be: been, have, are, become, is, were, being, by,
# Nearest to to: proactive, eccl, not, will, for, equine, would, towards,
# Nearest to has: had, have, is, was, having, legate, esterification, gained,
# Average loss at step 62000: 3.240263
# Average loss at step 64000: 3.248620
# Average loss at step 66000: 3.404504
# Average loss at step 68000: 3.392203
# Average loss at step 70000: 3.356860
# Nearest to its: their, his, the, her, whose, pencils, brush, earldom,
# Nearest to united: salad, census, amperes, city, sherwood, antebellum, arabized, lombardo,
# Nearest to most: more, less, many, some, use, among, anni, circulation,
# Nearest to or: and, transcendence, than, the, avid, kwanza, muggles, circumvent,
# Nearest to if: when, where, though, although, before, while, since, because,
# Nearest to on: upon, in, through, within, at, under, frenchmen, excised,
# Nearest to often: sometimes, usually, commonly, generally, frequently, now, typically, widely,
# Nearest to five: four, six, three, eight, seven, nine, zero, two,
# Nearest to many: some, several, various, these, all, most, numerous, both,
# Nearest to will: would, could, may, must, can, cannot, might, should,
# Nearest to th: bc, ce, st, ad, legalism, bce, rd, detachments,
# Nearest to had: has, have, was, were, fists, preview, received, been,
# Nearest to during: after, before, despite, in, at, until, throughout, through,
# Nearest to be: been, is, become, have, being, were, was, are,
# Nearest to to: will, would, in, must, may, can, for, and,
# Nearest to has: had, have, is, was, agnesi, although, padres, having,
# Average loss at step 72000: 3.375830
# Average loss at step 74000: 3.347874
# Average loss at step 76000: 3.307947
# Average loss at step 78000: 3.354368
# Average loss at step 80000: 3.379613
# Nearest to its: their, his, her, pencils, the, whose, our, earldom,
# Nearest to united: salad, census, amperes, following, antebellum, city, supreme, latter,
# Nearest to most: many, more, less, some, among, anni, especially, circulation,
# Nearest to or: and, than, expos, gaians, while, affray, pederastic, lubavitch,
# Nearest to if: when, though, where, since, before, although, botched, because,
# Nearest to on: upon, in, through, within, at, under, near, cumings,
# Nearest to often: sometimes, usually, commonly, generally, typically, frequently, now, also,
# Nearest to five: six, four, seven, eight, three, nine, two, zero,
# Nearest to many: some, several, various, these, most, numerous, all, both,
# Nearest to will: would, can, could, must, may, cannot, might, should,
# Nearest to th: bc, ce, bce, ad, rd, five, legalism, vestibule,
# Nearest to had: has, have, was, were, having, never, preview, received,
# Nearest to during: after, before, despite, when, in, throughout, through, until,
# Nearest to be: been, have, being, become, is, are, were, was,
# Nearest to to: would, must, will, eccl, ivo, panini, munda, could,
# Nearest to has: had, have, is, was, legate, having, watched, since,
# Average loss at step 82000: 3.410509
# Average loss at step 84000: 3.410569
# Average loss at step 86000: 3.393580
# Average loss at step 88000: 3.352871
# Average loss at step 90000: 3.364700
# Nearest to its: their, his, her, the, whose, pencils, our, chopped,
# Nearest to united: salad, following, latter, supreme, amperes, census, antebellum, lombardo,
# Nearest to most: more, less, many, especially, some, among, circulation, anni,
# Nearest to or: and, avid, screening, though, gaians, expos, ditko, com,
# Nearest to if: when, where, though, since, before, although, definitive, so,
# Nearest to on: upon, under, through, philologist, at, shire, kohlberg, chairmanship,
# Nearest to often: sometimes, usually, commonly, generally, typically, frequently, now, also,
# Nearest to five: seven, four, eight, six, three, nine, zero, two,
# Nearest to many: some, several, these, various, numerous, all, both, most,
# Nearest to will: would, can, could, must, may, might, cannot, should,
# Nearest to th: bc, ce, bce, rd, ad, st, vestibule, legalism,
# Nearest to had: has, have, was, were, having, preview, never, continued,
# Nearest to during: after, before, in, despite, throughout, when, through, until,
# Nearest to be: been, become, being, was, have, is, refer, were,
# Nearest to to: towards, would, eccl, will, jref, staffed, ineligible, jesuit,
# Nearest to has: had, have, is, was, since, having, legate, agnesi,
# Average loss at step 92000: 3.399770
# Average loss at step 94000: 3.252976
# Average loss at step 96000: 3.357767
# Average loss at step 98000: 3.241711
# Average loss at step 100000: 3.358849
# Nearest to its: their, his, her, pencils, the, whose, our, hamsters,
# Nearest to united: salad, census, latter, following, arabized, lombardo, supreme, amperes,
# Nearest to most: more, less, especially, particularly, among, many, circulation, some,
# Nearest to or: and, than, cornerback, rumble, affray, tristram, per, relic,
# Nearest to if: when, though, where, before, botched, since, although, while,
# Nearest to on: upon, at, within, through, in, under, protozoa, against,
# Nearest to often: sometimes, usually, commonly, generally, typically, frequently, now, widely,
# Nearest to five: four, six, eight, seven, three, nine, two, zero,
# Nearest to many: several, some, various, these, numerous, all, those, certain,
# Nearest to will: would, can, could, must, may, cannot, should, might,
# Nearest to th: rd, ce, bce, bc, ad, nd, vestibule, legalism,
# Nearest to had: has, have, was, having, preview, were, never, wanted,
# Nearest to during: after, before, in, despite, throughout, through, since, until,
# Nearest to be: been, being, have, are, become, were, is, superpower,
# Nearest to to: will, must, can, could, would, may, should, articulations,
# Nearest to has: had, have, is, was, since, having, gained, agnesi,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
