# %% [markdown]
# # 01. 설치모드에 대한 설명
#
#
# ### 처음 하둡을 공부할때, 그림과 같았다.
#
# 	스토리 텔링...그림 보기
# 	열심히 밑줄 긋고, 여러번 읽으면 ...
# ![](0_Intro/1_응팔_인용.png)
#
# ### 밑줄 긋기보다는 많이 사용하세요.
#
# 	집합은 수학공부할때, 다른 수학분야의 기초가 된다.
# 	그래서
# 	     집합이 어려워도 앞으로 고등학교 수학 공부를 진행하는데 어려움이 없는 만큼만 먼저 배운다.
# 	하둡 설치도 어려워도 앞으로          하둡 공부를 진행하는데 어려움이 없는 만큼만 먼저 배운다.
# 	정리하면 하둡 설치에 밑줄 긋지 마세요.
#
# ![](0_Intro/2_하둡설치_밑줄.png)
#
# ### 실행모드 3가지
#
# 	스토리 텔링...그림보기
# 	생라면, 설명대로 라면, 맛있는 라면
#
# 	프레임워크를 만든 경험을 반영했다.
# 	그냥 압축파일 풀면 끝	Standalone
# 	기본가이드를 따르면 ...	Pseudo-distributed
# 	복잡하지만 이상적인 ...	Fully-distrubuted
#
# 	실제 개발하는 순서를 반영했다.
# 	코드를 만들면서버그가 있는지 확인하고	Standalone
# 	만들어진 코드가 잘 작동하는지 확인하고	Pseudo-distributed
# 	실제 여러 서버에서 적용한다.			Fully-distributed
#
# 						HDFS-daemon	MapReduce-daemon	Purpose
# 	Standalone 			x			o					develop/debug
# 	Pseudo-distributed	o			o					test
# 	Fully-distrubuted	o			o					actually  ( Powerfull on 1000 nodes or more )
#
# ![](0_Intro/3_라면.png)

# %% [markdown]
# # 02. 설치
#
# ## VirtualBox 설치
#
# - https://www.virtualbox.org/wiki/Downloads
#
# ![](1_Install/1_VirtualBox/1_box.png)

# %% [markdown]
# ## Ubuntu 설치
# - https://ko.wikipedia.org/wiki/%EC%9A%B0%EB%B6%84%ED%88%AC_(%EC%9A%B4%EC%98%81_%EC%B2%B4%EC%A0%9C)
# - https://en.wikipedia.org/wiki/List_of_Linux_distributions
# - http://www.ubuntu.com/download/
# - /home/rwoo/Downloads/2_OS/2_Linux/0_Ubuntu
# ![](1_Install/2_Ubuntu/2_install_guide/1.png)
# ![](1_Install/2_Ubuntu/2_install_guide/2.png)
# ![](1_Install/2_Ubuntu/2_install_guide/3.png)
# ![](1_Install/2_Ubuntu/2_install_guide/4.png)
# ![](1_Install/2_Ubuntu/2_install_guide/5.png)
# ![](1_Install/2_Ubuntu/2_install_guide/6.png)
# ![](1_Install/2_Ubuntu/2_install_guide/7.png)
# ![](1_Install/2_Ubuntu/2_install_guide/8.png)
# ![](1_Install/2_Ubuntu/2_install_guide/9.png)
# ![](1_Install/2_Ubuntu/2_install_guide/10.png)
# ![](1_Install/2_Ubuntu/2_install_guide/11.png)
# ![](1_Install/2_Ubuntu/2_install_guide/12.png)
# ![](1_Install/2_Ubuntu/2_install_guide/13.png)
# ![](1_Install/2_Ubuntu/2_install_guide/14.png)
# ![](1_Install/2_Ubuntu/2_install_guide/15.png)
# ![](1_Install/2_Ubuntu/2_install_guide/16.png)
# ![](1_Install/2_Ubuntu/2_install_guide/17.png)
# ![](1_Install/2_Ubuntu/2_install_guide/18.png)
# ![](1_Install/2_Ubuntu/2_install_guide/19.png)
# ![](1_Install/2_Ubuntu/2_install_guide/20.png)
# ![](1_Install/2_Ubuntu/2_install_guide/21.png)
# ![](1_Install/2_Ubuntu/2_install_guide/22.png)
# ![](1_Install/2_Ubuntu/2_install_guide/23.png)

# %% [markdown]
# ## vboxadditions 설치
#
# ![](1_Install/2_Ubuntu/3_install_vboxadditions/1.png)
# ![](1_Install/2_Ubuntu/3_install_vboxadditions/2.png)
# ![](1_Install/2_Ubuntu/3_install_vboxadditions/3.png)
# ![](1_Install/2_Ubuntu/3_install_vboxadditions/4.png)
# ![](1_Install/2_Ubuntu/3_install_vboxadditions/5.png)
# ![](1_Install/2_Ubuntu/3_install_vboxadditions/6.png)

# %% [markdown]
# ## JAVA 설치
#
# ### openJDK1.7 설치
# ```
# # 1 install openJDK 1.7 by apt-get
#
# 	sudo apt-get install openjdk-7-jdk
#
# # purge openJDK 1.7 by apt-get
#
# 	sudo apt-get purge openjdk-7-jdk
# 	http://dreamlog.tistory.com/224
# ```
# ![](1_Install/3_Java/1-1_apt-get_openJDK1.7/1-1.png)
# ![](1_Install/3_Java/1-1_apt-get_openJDK1.7/1-2.png)
# ![](1_Install/3_Java/1-1_apt-get_openJDK1.7/1-3.png)
# ![](1_Install/3_Java/1-1_apt-get_openJDK1.7/1-4.png)
#
# ### oracleJDK1.7 설치
# - sudo apt-get install oracle-java7-installer
#
# ### Environment_Variable( 환경변수 설정 )
# ![](1_Install/3_Java/2_Environment_Variable/1.png)
# ![](1_Install/3_Java/2_Environment_Variable/2.png)
# ![](1_Install/3_Java/2_Environment_Variable/3.png)
# ![](1_Install/3_Java/2_Environment_Variable/4.png)
#
# ### check_install_by_Hello_World
# ![](1_Install/3_Java/3_check_install_by_Hello_World/1.png)
# ![](1_Install/3_Java/3_check_install_by_Hello_World/2.png)
# ![](1_Install/3_Java/3_check_install_by_Hello_World/3.png)

# %% [markdown]
# ## Hadoop 설치
#
# ### download_extract_hadoop
# - http://apache.mirror.cdnetworks.com/hadoop/common/
#
# ![](1_Install/4_Hadoop/1_download_extract_hadoop/1.png)
# ![](1_Install/4_Hadoop/1_download_extract_hadoop/3.png)
# ![](1_Install/4_Hadoop/1_download_extract_hadoop/4.png)
# ![](1_Install/4_Hadoop/1_download_extract_hadoop/5.png)
# ![](1_Install/4_Hadoop/1_download_extract_hadoop/6.png)
# ![](1_Install/4_Hadoop/1_download_extract_hadoop/7.png)
# ![](1_Install/4_Hadoop/1_download_extract_hadoop/8.png)
# ![](1_Install/4_Hadoop/1_download_extract_hadoop/9.png)
#
# ### environment_variable
# ![](1_Install/4_Hadoop/2_environment_variable/1.png)
# ![](1_Install/4_Hadoop/2_environment_variable/2.png)
#
# ### Standalone_Mode
# ![](1_Install/4_Hadoop/3_Standalone_Mode/1.png)
# ![](1_Install/4_Hadoop/3_Standalone_Mode/2.png)
# ![](1_Install/4_Hadoop/3_Standalone_Mode/3.png)
# ![](1_Install/4_Hadoop/3_Standalone_Mode/4.png)
# ![](1_Install/4_Hadoop/3_Standalone_Mode/5.png)
# ![](1_Install/4_Hadoop/3_Standalone_Mode/6.png)
# ![](1_Install/4_Hadoop/3_Standalone_Mode/7.png)
# ![](1_Install/4_Hadoop/3_Standalone_Mode/8.png)
# ![](1_Install/4_Hadoop/3_Standalone_Mode/9.png)
#
# ### Pseudo-Distributed_Mode
#
# ![](1_Install/4_Hadoop/4_Pseudo-Distributed_Mode/1.png)
# ![](1_Install/4_Hadoop/4_Pseudo-Distributed_Mode/2.png)
# ![](1_Install/4_Hadoop/4_Pseudo-Distributed_Mode/3.png)
# ![](1_Install/4_Hadoop/4_Pseudo-Distributed_Mode/4.png)
# ![](1_Install/4_Hadoop/4_Pseudo-Distributed_Mode/5.png)
# ![](1_Install/4_Hadoop/4_Pseudo-Distributed_Mode/6.png)
# ![](1_Install/4_Hadoop/4_Pseudo-Distributed_Mode/7.png)
# ![](1_Install/4_Hadoop/4_Pseudo-Distributed_Mode/8.png)
# ![](1_Install/4_Hadoop/4_Pseudo-Distributed_Mode/9.png)
# ![](1_Install/4_Hadoop/4_Pseudo-Distributed_Mode/10.png)
# ![](1_Install/4_Hadoop/4_Pseudo-Distributed_Mode/11.png)
# ![](1_Install/4_Hadoop/4_Pseudo-Distributed_Mode/12.png)
# ![](1_Install/4_Hadoop/4_Pseudo-Distributed_Mode/13.png)
# ![](1_Install/4_Hadoop/4_Pseudo-Distributed_Mode/14.png)
# ![](1_Install/4_Hadoop/4_Pseudo-Distributed_Mode/15.png)
# ![](1_Install/4_Hadoop/4_Pseudo-Distributed_Mode/16.png)
# ![](1_Install/4_Hadoop/4_Pseudo-Distributed_Mode/17.png)
# ![](1_Install/4_Hadoop/4_Pseudo-Distributed_Mode/18.png)
# ![](1_Install/4_Hadoop/4_Pseudo-Distributed_Mode/19.png)
# ![](1_Install/4_Hadoop/4_Pseudo-Distributed_Mode/20.png)
# ![](1_Install/4_Hadoop/4_Pseudo-Distributed_Mode/21.png)
# ![](1_Install/4_Hadoop/4_Pseudo-Distributed_Mode/22.png)
# ![](1_Install/4_Hadoop/4_Pseudo-Distributed_Mode/23.png)
# ![](1_Install/4_Hadoop/4_Pseudo-Distributed_Mode/24.png)
# ![](1_Install/4_Hadoop/4_Pseudo-Distributed_Mode/25.png)
# ![](1_Install/4_Hadoop/4_Pseudo-Distributed_Mode/26.png)
# ![](1_Install/4_Hadoop/4_Pseudo-Distributed_Mode/27.png)

# %% [markdown]
# # 03 Download
#
# ### WOO_RUNG
# ![](2_Download/1_WOO_RUNG/1_URL.png)
#
# ### CDH_cloudera_hadoop
# - http://www.cloudera.com/downloads/quickstart_vms/5-4.html
#
#
# ### HDP_hortonworks_data_platform
# - http://ko.hortonworks.com/hdp/downloads/
